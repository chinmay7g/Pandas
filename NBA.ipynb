# %%
import pandas as pd

# %%
nba = pd.read_csv(r'C:\Users\Administrator\Desktop\Python Test Data\nba.csv')

# %%
a = nba.groupby('Team')

# %%
b = a.first()

# %%
b
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
#now if we want to sort these players according to their heights, we can use sort values

c = nba.sort_values('Height')

# %%
c.head(20)
# Out:
#                  Name                  Team  Number Position   Age Height  \
# 203         Ty Lawson        Indiana Pacers    10.0       PG  28.0   5-11
# 22       Shane Larkin         Brooklyn Nets     0.0       PG  23.0   5-11
# 130      Phil Pressey          Phoenix Suns    25.0       PG  25.0   5-11
# 11      Isaiah Thomas        Boston Celtics     4.0       PG  27.0    5-9
# 384     D.J. Augustin        Denver Nuggets    12.0       PG  28.0    6-0
# 67         Kyle Lowry       Toronto Raptors     7.0       PG  30.0    6-0
# 394     Jameer Nelson        Denver Nuggets     1.0       PG  34.0    6-0
# 100        Chris Paul  Los Angeles Clippers     3.0       PG  31.0    6-0
# 305       Patty Mills     San Antonio Spurs     8.0       PG  27.0    6-0
# 57          Ish Smith    Philadelphia 76ers     1.0       PG  27.0    6-0
# 228        J.J. Barea      Dallas Mavericks     5.0       PG  31.0    6-0
# 152      Aaron Brooks         Chicago Bulls     0.0       PG  31.0    6-0
# ...

# %%
#using the previous methods learnt

players_by_height = nba.groupby('Team')['Height']

# %%
players_by_height.head(10)
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 448     6-8
# 449     6-8
# 450     6-8
# 451     6-6
# 457     NaN
# Name: Height, Length: 301, dtype: object

# %%
#using sort index

nba.set_index('Team').sort_index().head()
# Out:
#                            Name  Number Position   Age Height  Weight  \
# Team
# Atlanta Hawks   Lamar Patterson    13.0       SG  24.0    6-5   225.0
# Atlanta Hawks     Kent Bazemore    24.0       SF  26.0    6-5   201.0
# Atlanta Hawks  Tim Hardaway Jr.    10.0       SG  24.0    6-6   205.0
# Atlanta Hawks      Kirk Hinrich    12.0       SG  35.0    6-4   190.0
# Atlanta Hawks        Al Horford    15.0        C  30.0   6-10   245.0
#
#                     College      Salary
# Team
# Atlanta Hawks    Pittsburgh    525093.0
# Atlanta Hawks  Old Dominion   2000000.0
# Atlanta Hawks      Michigan   1304520.0
# Atlanta Hawks        Kansas   2854940.0
# Atlanta Hawks       Florida  12000000.0

# %%
#this method arranges alphabetically for the chosen parameter

# %%
pbh = nba.groupby('Team')['Weight'].mean()

# %%
pbh.head()
# Out:
# Team
# Atlanta Hawks        221.266667
# Boston Celtics       219.466667
# Brooklyn Nets        215.600000
# Charlotte Hornets    220.400000
# Chicago Bulls        218.933333
# Name: Weight, dtype: float64

# %%
player_info = nba.groupby('Team').agg({'Weight':'mean', 'Salary': 'mean', 'Age': 'count'})
player_info.head(20)
# Out:
#                             Weight        Salary  Age
# Team
# Atlanta Hawks           221.266667  4.860197e+06   15
# Boston Celtics          219.466667  4.181505e+06   15
# Brooklyn Nets           215.600000  3.501898e+06   15
# Charlotte Hornets       220.400000  5.222728e+06   15
# Chicago Bulls           218.933333  5.785559e+06   15
# Cleveland Cavaliers     227.866667  7.642049e+06   15
# Dallas Mavericks        227.000000  4.746582e+06   15
# Denver Nuggets          217.533333  4.294424e+06   15
# Detroit Pistons         222.200000  4.477884e+06   15
# Golden State Warriors   224.600000  5.924600e+06   15
# Houston Rockets         220.333333  5.018868e+06   15
# Indiana Pacers          222.266667  4.450122e+06   15
# Los Angeles Clippers    219.733333  6.323643e+06   15
# Los Angeles Lakers      227.066667  4.784695e+06   15
# Memphis Grizzlies       218.000000  5.467920e+06   18
# Miami Heat              218.400000  6.347359e+06   15
# ...
